# %%
import myRegression as reg
import pydataset as ps
import matplotlib.pyplot as plt

np = reg.pd.np
# Out:
# initiated datasets repo at: C:\Users\pwhee\.pydataset/

# %%
cars = ps.data('cars')
cars.head()
# Out:
#    speed  dist
# 1      4     2
# 2      4    10
# 3      7     4
# 4      7    22
# 5      8    16

# %%
plt.plot(cars)

# %%
cars_np = cars.to_numpy()

# %%
cars_np = np.transpose(cars_np)

# %%
plt.plot(cars_np)

# %%
cars_np2 = np.transpose(cars_np)
plt.scatter(cars_np2[0], cars_np2[1])

# %%
cars_np[0]
# Out:
# array([4, 2], dtype=int64)

# %%
import pandas as pd
s = pd.DataFrame(cars_np2)
s.to_csv("cars.csv")

# %%
print(cars_np2)
# Out:
# [[  4   4   7   7   8   9  10  10  10  11  11  12  12  12  12  13  13  13
#    13  14  14  14  14  15  15  15  16  16  17  17  17  18  18  18  18  19
#    19  19  20  20  20  20  20  22  23  24  24  24  24  25]
#  [  2  10   4  22  16  10  18  26  34  17  28  14  20  24  28  26  34  34
#    46  26  36  60  80  20  26  54  32  40  32  40  50  42  56  76  84  36
#    46  68  32  48  52  56  64  66  54  70  92  93 120  85]]

# %%
x = cars_np2[0]
y = cars_np2[1]
v = reg.leastSquaresRegressionLine(x, y)

# %%
print(v)
# Out:
# [[0.98506439 0.38174917]]

# %%
m,b = np.polyfit(x, y, 1)
print([m, b])
# Out:
# [3.932408759124087, -17.57909489051097]
